# %% [markdown]
# <a href="https://colab.research.google.com/github/Sindhura-tr/Machine_Learning_9_11am/blob/main/Association_Rule_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install apyori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=d927286e913caf5c26fa03e1c8deeb53d7202b153e9a231b41e48d233361c632
#   Stored in directory: /root/.cache/pip/wheels/77/3d/a6/d317a6fb32be58a602b1e8c6b5d6f31f79322da554cad2a5ea
# Successfully built apyori
# ...

# %% [markdown]
# ## Association Rule Mining

# %%
import pandas as pd
path = r"https://raw.githubusercontent.com/Sindhura-tr/Datasets/refs/heads/main/store_data.csv"
df = pd.read_csv(path,header=None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
df.shape
# Out:
# (7501, 20)

# %% [markdown]
# [[shrimp,almonds,avocado,......],
#  [burgers,meatballs,eggs],
#  [chutney],
#  ..
#  ..
#  ]

# %%
df.shape[0]
# Out:
# 7501

# %%
df.shape[1]
# Out:
# 20

# %%
df.values[0,0]
# Out:
# 'shrimp'

# %%
records = []
for i in range(df.shape[0]):
  records.append([str(df.values[i,j]) for j in range(df.shape[1])])
records[:50]
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %% [markdown]
# ## Criteria: Set the minimum values for Confidence, Support, Lift
#   Confidence = 0.2
#   support = 7*5/len(df)
#   lift = 3

# %%
conf = 0.2
sup = 35/len(df)
lift = 3

# %%
from apyori import apriori
association_rules = apriori(records,min_support=sup,min_confidence=conf,min_lift=lift)
association_rules = list(association_rules)
association_rules[0]
# Out:
# RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)])

# %%
# association rule
association_rules[0][0]
# Out:
# frozenset({'escalope', 'mushroom cream sauce'})

# %%
association_rules[0]

# %%
# support details
association_rules[0][1]
# Out:
# 0.005732568990801226

# %%
association_rules[0][2]
# Out:
# [OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]

# %%
association_rules[0][2][0]
# Out:
# OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)

# %%
# confidence details
association_rules[0][2][0][2]
# Out:
# 0.3006993006993007

# %%
# lift details
association_rules[0][2][0][3]
# Out:
# 3.790832696715049

# %%
len(association_rules)
# Out:
# 44

# %%
pair0 = association_rules[0][0]
items0 = []
for i in pair0:
  #print(i)
  items0.append(i)
items0
print("Associaiton rules: " + items0[0] + "----->" + items0[1])
# Out:
# Associaiton rules: escalope----->mushroom cream sauce

# %%
for item in association_rules:
  pair = item[0]

  items =[i for i in pair]
  print("Association Rule: " + items[0]  + "-------->" + items[1])

  sup = item[1]
  print("Support: "+str(item[1]))

  conf = str(item[2][0][2])
  lift = str(item[2][0][3])
  print("Confidence : "+ conf)
  print("Lift : "+lift)
  print("--------------------------------")
# Out:
# Association Rule: escalope-------->mushroom cream sauce
# Support: 0.005732568990801226
# Confidence : 0.3006993006993007
# Lift : 3.790832696715049
# --------------------------------
# Association Rule: escalope-------->pasta
# Support: 0.005865884548726837
# Confidence : 0.3728813559322034
# Lift : 4.700811850163794
# --------------------------------
# Association Rule: ground beef-------->herb & pepper
# Support: 0.015997866951073192
# Confidence : 0.3234501347708895
# Lift : 3.2919938411349285
# --------------------------------
# Association Rule: tomato sauce-------->ground beef
# Support: 0.005332622317024397
# Confidence : 0.3773584905660377
# Lift : 3.840659481324083
# --------------------------------
# Association Rule: olive oil-------->whole wheat pasta
# Support: 0.007998933475536596
# Confidence : 0.2714932126696833
# Lift : 4.122410097642296
# --------------------------------
# Association Rule: shrimp-------->pasta
# Support: 0.005065991201173177
# ...

# %%
rules = []
supports = []
confs = []
lifts =[]

for item in association_rules:
  pair = item[0]

  items =[i for i in pair]
  ru = (items[0]  + "-->" + items[1])
  rules.append(ru)


  sup = item[1]

  supports.append(sup)

  conf = (item[2][0][2])
  lift = (item[2][0][3])

  confs.append(conf)
  lifts.append(lift)

# %%
rules
# Out:
# ['escalope-->mushroom cream sauce',
#  'escalope-->pasta',
#  'ground beef-->herb & pepper',
#  'tomato sauce-->ground beef',
#  'olive oil-->whole wheat pasta',
#  'shrimp-->pasta',
#  'chocolate-->shrimp',
#  'spaghetti-->cooking oil',
#  'escalope-->mushroom cream sauce',
#  'escalope-->pasta',
#  'spaghetti-->ground beef',
#  'milk-->olive oil',
#  'mineral water-->shrimp',
#  'olive oil-->frozen vegetables',
#  'shrimp-->spaghetti',
#  'spaghetti-->tomatoes',
#  'grated cheese-->spaghetti',
#  'mineral water-->ground beef',
#  'ground beef-->herb & pepper',
#  'spaghetti-->ground beef',
#  'milk-->olive oil',
#  'tomato sauce-->ground beef',
#  'shrimp-->spaghetti',
#  'milk-->olive oil',
#  'mineral water-->olive oil',
#  'olive oil-->whole wheat pasta',
#  'shrimp-->pasta',
#  'pancakes-->olive oil',
#  'chocolate-->shrimp',
#  'spaghetti-->cooking oil',
#  'spaghetti-->ground beef',
#  'milk-->olive oil',
#  'mineral water-->shrimp',
#  'spaghetti-->olive oil',
# ...

# %%
supports
# Out:
# [0.005732568990801226,
#  0.005865884548726837,
#  0.015997866951073192,
#  0.005332622317024397,
#  0.007998933475536596,
#  0.005065991201173177,
#  0.005332622317024397,
#  0.004799360085321957,
#  0.005732568990801226,
#  0.005865884548726837,
#  0.008665511265164644,
#  0.004799360085321957,
#  0.007199040127982935,
#  0.005732568990801226,
#  0.005999200106652446,
#  0.006665777896280496,
#  0.005332622317024397,
#  0.006665777896280496,
#  0.015997866951073192,
#  0.006399146780429276,
#  0.004932675643247567,
#  0.005332622317024397,
#  0.005999200106652446,
#  0.007199040127982935,
#  0.005199306759098787,
#  0.007998933475536596,
#  0.005065991201173177,
#  0.005065991201173177,
#  0.005332622317024397,
#  0.004799360085321957,
#  0.008665511265164644,
#  0.004799360085321957,
#  0.007199040127982935,
#  0.005732568990801226,
#  0.005999200106652446,
#  0.006665777896280496,
#  0.005332622317024397,
#  0.006665777896280496,
#  0.006399146780429276,
#  0.004932675643247567,
# ...

# %% [markdown]
# ## Create a dictionary to save the associations formed

# %%
dct = {
    "Rules":rules,
    "Support":supports,
    "Confidence":confs,
    "Lift":lifts
}

# %%
from typing_extensions import final
final_associations = pd.DataFrame(dct)
final_associations
# Out:
#                               Rules   Support  Confidence      Lift
# 0   escalope-->mushroom cream sauce  0.005733    0.300699  3.790833
# 1                  escalope-->pasta  0.005866    0.372881  4.700812
# 2       ground beef-->herb & pepper  0.015998    0.323450  3.291994
# 3        tomato sauce-->ground beef  0.005333    0.377358  3.840659
# 4     olive oil-->whole wheat pasta  0.007999    0.271493  4.122410
# 5                    shrimp-->pasta  0.005066    0.322034  4.506672
# 6                chocolate-->shrimp  0.005333    0.232558  3.254512
# 7           spaghetti-->cooking oil  0.004799    0.571429  3.281995
# 8   escalope-->mushroom cream sauce  0.005733    0.300699  3.790833
# 9                  escalope-->pasta  0.005866    0.372881  4.700812
# 10          spaghetti-->ground beef  0.008666    0.311005  3.165328
# 11                 milk-->olive oil  0.004799    0.203390  3.088314
# 12           mineral water-->shrimp  0.007199    0.305085  3.200616
# ...

# %% [markdown]
# ## Save the results to output file

# %%
final_associations.to_csv("Associations_Ready.csv",index=False)
